# %% [markdown]
# <a href="https://colab.research.google.com/github/celiaferreira/Covid19_RX/blob/master/9_Conclusoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 9. Conclusões
#
# Nesta secção apresentam-se os resultados finais e as conclusões.

# %% [markdown]
# ### 9.1 Comparação  de técnicas para aumentar dados
#
# Para aumentar o número de registos no conjunto de treino e balancear as labels foram testadas duas técnicas: oversampling e data generation dos casos COVID.
#
# **Conclui-se que**:
#  * Os resultados são interessantes em ambas as técnicas, tendo-se obtido elevado valor preditivo.
#
#  * No entanto, o oversampling resulta em performances ligeiramente superiores.
#
#  * O DataGeneration consome muitos recursos computacionais e tomando um elevado tempo para gerar as imagens.
#
#
#  Assim, recomenda-se o oversamplig como técnica para gerar novos registos e tornar o conjunto de treino balanceado.

# %% [markdown]
# ### 9.1 Comparação de resultados
#
# Os gráficos abaixo comparam a evolução da accuracy pelas epochs para os modelos testados, para o conjunto de treino (aumentado recorrendo a oversampling) e de validação.

# %% [markdown]
# ### 9.1.1 Modelos de deep learning
#
# * **Train set**

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

with plt.style.context('Solarize_Light2'):
    plt.plot((history_cnn3.history['accuracy']),label='CNN', linestyle='-.', color='b')
    plt.plot((history_api1.history['accuracy']),label='API1', color='k')
    plt.plot((history_api2.history['accuracy']),label='API2', linestyle=':', color='y')
    plt.plot((history_api3.history['accuracy']),label='API3', linestyle='--', color='r')
    plt.plot((best_history.history['accuracy']),label='best_model', color='g')

    plt.title('ACCURACY CNN - Line')
    plt.xlabel('# epochs', fontsize=14)
    plt.ylabel('accuracy', fontsize=14)
    ax = plt.subplot(111)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    #plt.legend(loc='best')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# * **Validation set**

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

with plt.style.context('Solarize_Light2'):
    plt.plot((history_cnn3.history['val_accuracy']),label='CNN', linestyle='-.', color='b')
    plt.plot((history_api1.history['val_accuracy']),label='API1', color='k')
    plt.plot((history_api2.history['val_accuracy']),label='API2', linestyle=':', color='y')
    plt.plot((history_api3.history['val_accuracy']),label='API3', linestyle='--', color='r')
    plt.plot((best_history.history['val_accuracy']),label='best_model', color='g')

    plt.title('VAL ACCURACY CNN - Line')
    plt.xlabel('# epochs', fontsize=14)
    plt.ylabel('accuracy', fontsize=14)
    ax = plt.subplot(111)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    axes = plt.gca()
    axes.set_ylim([0.6,1])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    #plt.legend(loc='best')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# Constata-se que:
# * O melhor modelo é obtido com otimização de hiperparâmetros (validation set).
#
# * Modelos API (mais complexos) com performance competitiva, mas não superam o modelo ótimo.
#
# * Modelo API apresentam maior overfitting (treino tem early stopping mais precoce devido ao aumento do erro no conjunto de validação).

# %% [markdown]
# ### 9.1.2 Modelos de transfer learning
#
# * **Train set**

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

with plt.style.context('Solarize_Light2'):
    plt.plot((history11c.history['accuracy']),label='TL_IncepNone', color='b')
    plt.plot((history12.history['accuracy']),label='TL_ResNetFrozen',linestyle='--')
    plt.plot((history13.history['accuracy']),label='TL_ResNetTuned')

    plt.title('ACCURACY CNN - Line')
    plt.xlabel('# epochs', fontsize=14)
    plt.ylabel('accuracy', fontsize=14)
    ax = plt.subplot(111)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    #plt.legend(loc='best')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# * **Validation set**

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

with plt.style.context('Solarize_Light2'):
    plt.plot((history11c.history['val_accuracy']),label='TL_IncepNone', color='b')
    plt.plot((history12.history['val_accuracy']),label='TL_ResNetFrozen',linestyle='--')
    plt.plot((history13.history['val_accuracy']),label='TL_ResNetTuned')

    plt.title('VAL ACCURACY CNN - Line')
    plt.xlabel('# epochs', fontsize=14)
    plt.ylabel('accuracy', fontsize=14)
    ax = plt.subplot(111)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    axes = plt.gca()
    axes.set_ylim([0.,1])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# Constata-se que:
#
# * Os modelos de transfer learning sendo mais complexos demoram mais tempo a concluir cada epoch.
#
# * Modelos de transfer learning com pesos congelados apresentam a pior performance.
#
# * Modelos de transfer learning apresentam maiores oscilações na aprendizagem.
#
# * Modelos de transfer learning com pesos re-treinados convergem mais rapidamente, atingindo elevados valores de precisão (modelo TL_IncepNone).

# %% [markdown]
# ### 9.1.3 Accuracy global
#
# O gráfico abaixo compara a accuracy global obtida por cada algoritmo para o problema de classificação de imagens pulmonares como COVID-19, outras pneumonias ou situações normais.

# %%
CNN3=((history_cnn3.history['val_accuracy'])[-1])*100

API1=((history_api1.history['val_accuracy'])[-1])*100
API2=((history_api2.history['val_accuracy'])[-1])*100
API3=((history_api3.history['val_accuracy'])[-1])*100
Optimal=((best_history.history['val_accuracy'])[-1])*100
TL_IncepF=((history11.history['val_accuracy'])[-1])*100
TL_IncepT=((history11b.history['val_accuracy'])[-1])*100
TL_IncepNone=((history11c.history['val_accuracy'])[-1])*100
TL_ResNetF=((history12.history['val_accuracy'])[-1])*100
TL_ResNetT=((history13.history['val_accuracy'])[-1])*100

plt.figure(figsize=(20,5))
ind = np.arange(12)
width = 0.2

labels = ['RF', 'AdaBoost','KNN','CNN', 'API1', 'API2','API3','Optimal','TL_IncepFrozen','TL_IncepTuned','TL_IncepNone','TL_ResNetFrozen','TL_ResNetTuned']
bar_08 = plt.bar(ind, [90.9,65.1, 90.9,CNN3,API1,API2,API3,Optimal,TL_IncepF,TL_IncepT,TL_IncepNone,TL_ResNetF,TL_ResNetT],width, color='g', label='val_accuracy')
location = ind+width/2
labels=labels
plt.xticks(location, labels)
axes = plt.gca()
axes.set_ylim([80,100])
plt.legend(loc='best')

# %% [markdown]
# * Nos modelos de ML, as random forest (RF) e o KNN tiveram a mehor performance.
#
# * Mesmo num problema de classificação de imagens, os modelos de machine learning tradicionais apresentam uma performance competitiva, superior a 90%.
#
# * De um modo geral, os modelos de deep learning são preditivos, destacando-se o modelo otimizado.
#
# * A complexidade acrescida nas API2 e API3 não se traduziu num ganho efetivo na performance, sendo o erro global comprometido pelo aumento da variância.
#
# * Os modelos de transfer learning com pesos congelados não se revelaram competitivos. Neste caso, o melhor resultado foi obtido pela utilização da arquitetura da rede, mas permitindo o treino dos pesos e a extração de features mais direcionadas para o problema em análise.

# %% [markdown]
# ### 9.2 Modelo final proposto

# %% [markdown]
# Tendo em consideração a performance global, o recall dos casos COVID e a ausência de overfitting, **propõe-se como ideal o modelo obtido mediante otimização de hiperparâmetros**, que apresenta a seguinte topologia:

# %%
model = models.Sequential()
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(200, 200, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
model.compile(optimizers.Adam(lr=0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Este modelo distingue o COVID-19, de outras pneumonias e das situações normais com uma precisão de 97,3% no conjunto de teste, tendo um recall de 98,1% dos casos COVID-19.

# %% [markdown]
# Segundo os objetivos, este projeto:
#
# * Apresenta uma proposta de um modelo generalizável para a população, que permite identificar com elevada precisão o COVID-19 em imagens de raio-X.
#
# * Os resultados finais são impulsionados pela utilização de
#
#  - oversampling/datageneration para a obtenção de um dataset balanceado
#  - dropout, early stopping e topolgia das redes que mitigam o overfitting
#  - uma otimização de hiperparâmetros.
#
# * De forma exploratória, compara a performance de vários algoritmos: machine learning, deep learning e transfer learning.
#
# * Inclui visualizações de imagens, resultados e aprendizagem em curso.
